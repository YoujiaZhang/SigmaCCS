# %%
logo = '   _____ _  _____ __  __          \n  / ____(_)/ ____|  \/  |   /\    \n | (___  _| |  __| \  / |  /  \   \n'\
       '  \___ \| | | |_ | |\/| | / /\ \  \n  ____) | | |__| | |  | |/ ____ \ \n |_____/|_|\_____|_|  |_/_/    \_\ '
print(logo)
# Out:
#    _____ _  _____ __  __
#   / ____(_)/ ____|  \/  |   /\
#  | (___  _| |  __| \  / |  /  \
#   \___ \| | | |_ | |\/| | / /\ \
#   ____) | | |__| | |  | |/ ____ \
#  |_____/|_|\_____|_|  |_/_/    \_\

# %%
import pickle
from parameter import *

# %%
p = Parameter(adduct_SET = ['[M+H]+', '[M+Na]+', '[M-H]-'], 
              All_Atoms = ['As', 'Br', 'C', 'Cl', 'F', 'I', 'N', 'O', 'P', 'S', 'Se'], 
              Max_Coor = 15.615155868453662, 
              Min_Coor = -15.475082312818216)
with open('D:/Jupyter-Notebook-Zyj/项目代码文件/pred-test/parameter.pkl',"wb") as file:
    pickle.dump(p, file, True)

# %%
from ECC import *

# %%
# ifile = 'C:/Users/Administrator/Desktop/ALLCCS/data/Alldata.csv'
# ParameterPath = 'D:/Jupyter-Notebook-Zyj/项目代码文件/train-test/parameter.pkl'
# ofile = 'D:/Jupyter-Notebook-Zyj/项目代码文件/train-test/model.h5'
# ofileDataPath = 'D:/Jupyter-Notebook-Zyj/项目代码文件/train-test/'

# ECC_Model = Model_train(ifile, ParameterPath, ofile, ofileDataPath)
# Out:
# ## 读取了数据数量 :  100
# ## All element types :  ['C', 'I', 'N', 'O', 'P', 'S']
# ## All adduct types :  ['[M+H]+', '[M+Na]+', '[M-H]-']
# ## Build graph data successfully
# ## Dataset: MyDataset(n_graphs=100)  Node features: (12, 18)
# D:\Anaconda\envs\ecc\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# D:\Anaconda\envs\ecc\lib\site-packages\numpy\core\_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# ...

# %%
import pickle
from parameter import *

p = Parameter(adduct_SET = ['[M+H]+', '[M+Na]+', '[M-H]-'], 
              All_Atoms = ['As', 'Br', 'C', 'Cl', 'F', 'I', 'N', 'O', 'P', 'S', 'Se'], 
              Max_Coor = 15.615155868453662, 
              Min_Coor = -15.475082312818216)
with open('D:/Jupyter-Notebook-Zyj/项目代码文件/pred-test/parameter.pkl',"wb") as file:
    pickle.dump(p, file, True)

from ECC import *

# ifile = 'D:/Jupyter-Notebook-Zyj/data/END/alldata.csv'
# 输入文件
ifile = r'C:\Users\Administrator\Desktop\6.17daibijiao.csv'
#参数文件
ParameterPath = 'D:/Jupyter-Notebook-Zyj/项目代码文件/pred-test/parameter.pkl'
#模型文件
mfileh5 = 'D:/Jupyter-Notebook-Zyj/model/GCNCCS-modelECC3-ALL.h5'
#输出文件
ofile = r'C:\Users\Administrator\Desktop\6.17daibijiao'+'ECC3-AL'+'.csv'

Model_prediction(ifile,ParameterPath,mfileh5,ofile,Isevaluate=True)
# Out:
# ## Read data :  2279
# ## All Atoms  :  ['As', 'Br', 'C', 'Cl', 'F', 'I', 'N', 'O', 'P', 'S', 'Se']
# ## All Adduct :  ['[M+H]+', '[M+Na]+', '[M-H]-']
# 2278 CC(CCCC(C)(C)O)C1CCC2C1(CCCC2=CC=C3CC(CCC3=C)O)C [M+H]+ 208.6982
# ## 3D coordinates generated successfully
# {'N': 0.38613861386138615, 'Se': 0.8316831683168316, 'F': 0.31683168316831684, 'Co': 0.7821782178217822, 'O': 0.3069306930693069, 'As': 0.8811881188118812, 'Br': 0.8118811881188119, 'Cl': 0.6633663366336634, 'S': 0.7029702970297029, 'C': 0.42574257425742573, 'P': 0.7821782178217822, 'I': 1.0, 'H': 0.0}
# {'N': 0.1032498671726695, 'Se': 0.6191756039662093, 'F': 0.14289880110277858, 'Co': 0.46010207747584464, 'As': 0.5870984688775774, 'O': 0.11907762668280056, 'Br': 0.6266738249259133, 'Cl': 0.2735981682735815, 'S': 0.24668718033769474, 'C': 0.08739526021884797, 'P': 0.2380194434270746, 'I': 1.0, 'H': 0.0}
# ...

# %%
ifile = 'C:/Users/Administrator/Desktop/ALLCCS/data/Alldata.csv'
ParameterPath = 'D:/Jupyter-Notebook-Zyj/项目代码文件/pred-test/parameter.pkl'
mfileh5 = 'D:/Jupyter-Notebook-Zyj/model/GCNCCS-model'+NUM+'.h5'
ofile = 'D:/Jupyter-Notebook-Zyj/项目代码文件/pred-test/pred.csv'

Model_prediction(ifile,ParameterPath,mfileh5,ofile,Isevaluate=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-50e2ed417b8d> in <module>
#       4 ofile = 'D:/Jupyter-Notebook-Zyj/项目代码文件/pred-test/pred.csv'
#       5
# ----> 6 Model_prediction(ifile,ParameterPath,mfileh5,ofile,Isevaluate=True)
#
# D:\Jupyter-Notebook-Zyj\项目代码文件\ECC.py in Model_prediction(ifile, ParameterPath, mfileh5, ofile, Isevaluate)
#      16     * Isevaluate    : Evaluate ?
#      17     '''
# ---> 18     smiles, adduct, ccs = read_data(ifile)
#      19 #     XIBA = 100
#      20 #     smiles, adduct, ccs = smiles[:XIBA], adduct[:XIBA], ccs[:XIBA]
#
# D:\Jupyter-Notebook-Zyj\项目代码文件\GraphData.py in read_data(filename)
#      19     * ccs    : CCS
#      20     '''
# ---> 21     data = pd.read_csv(filename)
#      22     smiles = np.array(data['SMILES'])
#      23     adduct = np.array(data['Adduct'])
#
# ...
